                   ,0.7550244975502449
                   ,0.7601239876012399
                   ,0.7608239176082392
                   ,0.7672232776722328
                   ,0.7704229577042295
                   ,0.7706229377062294
                   ,0.7686231376862314
                   ,0.7763223677632237
                   ,0.7758224177582241
                   ,0.7775222477752225
                   ,0.7782221777822218]

CIFAR10_FF = [0.0861913808619138
             ,0.22087791220877911
             ,0.37306269373062695
             ,0.4530546945305469
             ,0.49905009499050096
             ,0.5228477152284772
             ,0.5404459554044595
             ,0.5526447355264473
             ,0.5685431456854314
             ,0.5740425957404259
             ,0.5785421457854215
             ,0.5882411758824118
             ,0.5946405359464053
             ,0.5953404659534046
             ,0.6039396060393961
             ,0.6043395660433957
             ,0.6082391760823918
             ,0.6091390860913909
             ,0.6126387361263873
             ,0.6158384161583842
             ,0.6168383161683831]

# %%
import numpy as np
import math
import matplotlib
import matplotlib.pylab as plt

###############################################################
################ Plot the records for CIFAR10 #################
###############################################################

fig, ax = plt.subplots(figsize=(8,6),dpi=600)
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)
    ax.spines[axis].set_color("black")
    ax.spines[axis].set_zorder(0)
plt.plot(CIFAR10_FF,color='b', linestyle='-', marker='^',markevery=2, markersize=10)
plt.plot(CIFAR10_real,color='r',linestyle='-', markevery=2, marker='X', markersize=10)
plt.xlabel('# Iterations\n',fontweight='bold', fontsize=24)
plt.ylabel('Accuracy',fontweight='bold', fontsize=24)
plt.grid()
plt.rc('xtick', labelsize=23) 
plt.rc('ytick', labelsize=23) 
lgnd = plt.legend(['CLOVER', 'Conventional Neural Network'], fontsize=21)
lgnd.legendHandles[0]._legmarker.set_markersize(15)
lgnd.legendHandles[1]._legmarker.set_markersize(15)
# lgnd.legendHandles[2]._legmarker.set_markersize(15)
# plt.rcParams["figure.figsize"] = (6, 3)
# plt.rcParams['lines.linewidth'] = 1.5
plt.savefig("acc_CIFAR_update.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib
import matplotlib.pylab as plt

#############################################################
################ Plot the records for MNIST #################
#############################################################

fig, ax = plt.subplots(figsize=(8,6),dpi=600)
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)
    ax.spines[axis].set_color("black")
    ax.spines[axis].set_zorder(0)
plt.plot(MNIST_FF,color='b', linestyle='-', marker='^',markevery=2, markersize=10)
plt.plot(MNIST_real,color='r',linestyle='-', markevery=2, marker='X', markersize=10)
plt.xlabel('# Iterations\n',fontweight='bold', fontsize=24)
plt.ylabel('Accuracy',fontweight='bold', fontsize=24)
plt.grid()
plt.rc('xtick', labelsize=23) 
plt.rc('ytick', labelsize=23) 
lgnd = plt.legend(['CLOVER', 'Conventional Neural Network'], fontsize=21)
lgnd.legendHandles[0]._legmarker.set_markersize(15)
lgnd.legendHandles[1]._legmarker.set_markersize(15)
# lgnd.legendHandles[2]._legmarker.set_markersize(15)
# plt.rcParams["figure.figsize"] = (6, 3)
# plt.rcParams['lines.linewidth'] = 1.5
plt.savefig("acc_MNIST_update.png")
plt.show()
